# %% [markdown]
# <a href="https://colab.research.google.com/github/alifars/torch101/blob/main/4_binary_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data

# %%
from sklearn.datasets import make_moons
X,y = make_moons(n_samples=200, noise = 0.2)
print(X.shape)
print(y.shape)
# Out:
# (200, 2)
# (200,)

# %%
print()
# Out:
# [ 0.95020132 -0.15742002  0.47223787  2.23370208  0.62652889  0.53061623
#   0.50560758 -0.22061788  0.27005349  0.81246208 -0.0027467  -0.11545437
#   0.84867189  1.19971709 -0.4817833   0.00358049  0.42665766  0.54717709
#  -0.62430603  0.12384231  0.9706784   0.45174011  0.19423337 -0.00773316
#   1.08303362  0.54361692  0.68057363  0.79038671  2.14319529  0.99392625
#   1.74791725  1.01763594  1.46980552  1.74976774  0.17197885  1.26374265
#  -0.19915225  1.58043972  0.05477115  0.90371521 -0.89134418 -1.01731745
#   0.71574239  1.32859629 -0.66845594  0.8075739   0.53649633 -0.78712873
#   1.49139501 -0.00576744  1.74333953  0.89592265  0.80341589 -0.13526508
#  -1.0885173  -0.04689348 -0.22703168 -1.09313164 -1.21520396  0.68028804
#   0.57282478  0.31303378  0.49822471  0.69562586  0.89375733  0.62501439
#  -0.70814556  0.86674973  2.00602616  0.50924448  1.05646158  0.38245569
#   0.78361083 -0.96474333 -0.64265606  1.39923058  0.38721101  0.97846722
# ...

# %%
# plot the dataset
from matplotlib import pyplot as plt

plt.scatter(X[:,0],X[:,1], c = y)
plt.title("make moon dataset")
# Out:
# Text(0.5, 1.0, 'make moon dataset')

# %%
import torch
# convert data ro tensors
X_tensor = torch.from_numpy(X)
y = torch.from_numpy(y)

# %% [markdown]
# # torch Dataset, random_split, torch DataLoader

# %%
# make a torch Dataset

# %%
X_train.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-d2ba684acd0f> in <cell line: 1>()
# ----> 1 X_train.shape
#
# AttributeError: 'Subset' object has no attribute 'shape'
