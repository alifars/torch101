# %% [markdown]
# <a href="https://colab.research.google.com/github/alifars/torch101/blob/main/imdb_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
from torchtext.datasets import IMDB

# %%
pip install 'portalocker>=2.0.0'

# %%
# import datasets
from torchtext.legacy import datasets

train_data, test_data = datasets.IMDB.splits(TEXT, LABEL)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-7c0bd1c8047e> in <cell line: 2>()
#       1 # import datasets
# ----> 2 from torchtext.legacy import datasets
#       3
#       4 train_data, test_data = datasets.IMDB.splits(TEXT, LABEL)
#
# ModuleNotFoundError: No module named 'torchtext.legacy'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
for label, line in train_iter:
  print(label)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-be7c04d76742> in <cell line: 1>()
# ----> 1 for label, line in train_iter:
#       2   print(label)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/datapipes/_hook_iterator.py in wrap_generator(*args, **kwargs)
#     181                         response = gen.send(None)
#     182                 else:
# --> 183                     response = gen.send(None)
#     184
#     185                 while True:
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/datapipes/iter/sharding.py in __iter__(self)
#      73
#      74     def __iter__(self):
# ---> 75         for i, item in enumerate(self.source_datapipe):
#      76             if i % self.num_of_instances == self.instance_id:
#      77                 yield item
#
# ...
